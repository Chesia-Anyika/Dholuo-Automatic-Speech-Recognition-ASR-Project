# %%
#filter tsv files
import pandas as pd
import os

# Import the drive module from Google Colab
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import os

# Paths to your files
devtsv_path = "/content/drive/My Drive/ASR/dev.tsv"
traintsv_path = "/content/drive/My Drive/ASR/train.tsv"
testtsv_path = "/content/drive/My Drive/ASR/test.tsv"
audio_folder = "/content/drive/My Drive/clips_wav"

# Paths to save filtered files
filtered_dev_path = "/content/drive/My Drive/ASR/filtered_dev.tsv"
filtered_train_path = "/content/drive/My Drive/ASR/filtered_train.tsv"
filtered_test_path = "/content/drive/My Drive/ASR/filtered_test.tsv"

# Get a set of available audio files in the audio folder (without extensions)
audio_files = set(f.replace('.wav', '') for f in os.listdir(audio_folder) if f.endswith('.wav'))

# Function to filter and modify paths in a TSV file
def filter_tsv(input_tsv_path, output_tsv_path):
    try:
        # Load the TSV file
        df = pd.read_csv(input_tsv_path, sep='\t', on_bad_lines='skip', engine='python')

        # Ensure the 'path' column is a string and replace .mp3 with .wav
        df['path'] = df['path'].astype(str).str.replace('.mp3', '.wav', regex=False)

        # Filter the rows based on whether the file exists in the audio folder
        df['file_exists'] = df['path'].apply(lambda x: os.path.basename(x).replace('.wav', '') in audio_files)

        # Filter out rows where the file does not exist
        filtered_df = df[df['file_exists']].copy()  # Make a copy of the filtered DataFrame

        # Drop the helper column
        filtered_df.drop(columns=['file_exists'], inplace=True)

        # Save the updated TSV file
        filtered_df.to_csv(output_tsv_path, sep='\t', index=False)
        print(f"Updated {input_tsv_path} and saved to {output_tsv_path}")
    except Exception as e:
        print(f"Error processing {input_tsv_path}: {e}")

# Filter each TSV file
filter_tsv(devtsv_path, filtered_dev_path)
filter_tsv(traintsv_path, filtered_train_path)
filter_tsv(testtsv_path, filtered_test_path)
# Out:
# Updated /content/drive/My Drive/ASR/dev.tsv and saved to /content/drive/My Drive/ASR/filtered_dev.tsv
# Updated /content/drive/My Drive/ASR/train.tsv and saved to /content/drive/My Drive/ASR/filtered_train.tsv
# Updated /content/drive/My Drive/ASR/test.tsv and saved to /content/drive/My Drive/ASR/filtered_test.tsv

# %%
# Paths to your files
audio_folder = "/content/drive/My Drive/clips_wav"

# Step 4: Get list of audio files in 'clips_wav'
audio_files = set(f.split('.')[0] for f in os.listdir(audio_folder) if f.endswith('.wav'))
print(f"Found {len(audio_files)} audio files.")
# Out:
# Found 12962 audio files.

# %%
import pandas as pd

# Paths to your TSV files
devtsv_path = "/content/drive/My Drive/ASR/dev.tsv"
traintsv_path = "/content/drive/My Drive/ASR/train.tsv"
testtsv_path = "/content/drive/My Drive/ASR/test.tsv"

# Function to read TSV files into DataFrames
def read_tsv_resiliently(file_path):
    try:
        # Read the TSV file, skipping bad lines and using the 'python' engine for compatibility
        df = pd.read_csv(file_path, sep='\t', on_bad_lines='skip', engine='python')
        print(f"Successfully loaded {file_path}")
        return df
    except Exception as e:
        print(f"Error reading {file_path}: {e}")
        return None

# Read the TSV files
train_df = read_tsv_resiliently(traintsv_path)
test_df = read_tsv_resiliently(testtsv_path)
dev_df = read_tsv_resiliently(devtsv_path)

# Optional: Print the first few rows of the DataFrames to verify
if train_df is not None:
    print(train_df.head())
if test_df is not None:
    print(test_df.head())
if dev_df is not None:
    print(dev_df.head())
# Out:
# Successfully loaded /content/drive/My Drive/ASR/train.tsv
# Successfully loaded /content/drive/My Drive/ASR/test.tsv
# Successfully loaded /content/drive/My Drive/ASR/dev.tsv
#                                            client_id  \
# 0  76220259d4c614b1876412e489524ede62b700927b202d...
# 1  76220259d4c614b1876412e489524ede62b700927b202d...
# 2  76220259d4c614b1876412e489524ede62b700927b202d...
# 3  76220259d4c614b1876412e489524ede62b700927b202d...
# 4  76220259d4c614b1876412e489524ede62b700927b202d...
#
#                             path  \
# 0  common_voice_luo_40228998.mp3
# 1  common_voice_luo_40228999.mp3
# 2  common_voice_luo_40229003.mp3
# 3  common_voice_luo_40229004.mp3
# 4  common_voice_luo_40229005.mp3
#
#                                          sentence_id  \
# 0  0b6d23f21850cf38f2da23b85e5b9d243e327f4e1a987c...
# 1  0093b37219cd1409b042fc7c111546d1338a34dfa32d04...
# 2  11417bdb395c6a8e9095f673662428f371c1ffea41a4d7...
# 3  1199d8ab1254d0772d3efa7f1f6113881809fc6c80aff5...
# 4  058ef183ec6c447b759aab31e64c8d9b1c0086828801d0...
#
#                                             sentence      sentence_domain  \
# 0  ber ka inyiso pachi kaluwore gi weche miwacho ...              general
# 1  Ne iparo ni gik ma kamago ne nyalo kelo chandr...              general
# 2     A. mar Bedo ng'at maduong' en gima tek ahinya.              general
# 3                         Nyaka bed ni nitie chik ma  technology_robotics
# 4    Sani weche mag ohala isomo embalariany ng’enyne              general
#
#    up_votes  down_votes  age gender  accents  variant locale  segment
# 0         2           0  NaN    NaN      NaN      NaN    luo      NaN
# 1         2           1  NaN    NaN      NaN      NaN    luo      NaN
# 2         2           0  NaN    NaN      NaN      NaN    luo      NaN
# 3         2           0  NaN    NaN      NaN      NaN    luo      NaN
# 4         2           0  NaN    NaN      NaN      NaN    luo      NaN
#                                            client_id  \
# 0  01d056dd20b981117632e060d72c99b78271c35d971f5c...
# 1  5084426734db1876936ae7bbdd72858a654bc46877a588...
# 2  95c77443ff068f953bfe4a14471b18f4cc94a08c74a771...
# 3  dd2c93e373aa566aed23d052723a253bc4a0ea604b8cbb...
# 4  d8dee50072545349474f2766b1e41c035e725eab1e68f3...
#
#                             path  \
# 0  common_voice_luo_40609150.mp3
# 1  common_voice_luo_40636306.mp3
# 2  common_voice_luo_40258074.mp3
# 3  common_voice_luo_40833291.mp3
# 4  common_voice_luo_40820771.mp3
#
#                                          sentence_id  \
# 0  6a460e6ea255a011d13f980e2a317c35cb280d34b38772...
# 1  69ca449ccd58626ad3b0bdf9e787d00231d9dcf5082cca...
# 2  2d7ad3d79559dac77efe62807164187364c57e8fdf1ebc...
# 3  0b1db575a4a02a44caa5e0538da4754a121d7f251bab7f...
# 4  616c471e1f2909c0c168c5096123ca27ad56c9664ed880...
#
#                                             sentence       sentence_domain  \
# 0                               waduto wakalo e pek.               general
# 1                                  Wayu nyinge ng’a?               general
# 2                         Swahili e lando wach maber               general
# 3                            Ango motimo wang dheno.      agriculture_food
# 4  Ikruok ochako kawuono motelo ne chako ayanga p...  news_current_affairs
#
#    up_votes  down_votes       age gender  accents  variant locale  segment
# 0         2           0       NaN    NaN      NaN      NaN    luo      NaN
# 1         2           0  twenties    NaN      NaN      NaN    luo      NaN
# 2         2           0  twenties    NaN      NaN      NaN    luo      NaN
# 3         2           0  thirties    NaN      NaN      NaN    luo      NaN
# 4         2           0  thirties    NaN      NaN      NaN    luo      NaN
#                                            client_id  \
# 0  6d243f0d9779d2cfbffbe09729b57546067abca6c16f0d...
# 1  6d243f0d9779d2cfbffbe09729b57546067abca6c16f0d...
# 2  6d243f0d9779d2cfbffbe09729b57546067abca6c16f0d...
# 3  6d243f0d9779d2cfbffbe09729b57546067abca6c16f0d...
# 4  6d243f0d9779d2cfbffbe09729b57546067abca6c16f0d...
#
#                             path  \
# 0  common_voice_luo_40556704.mp3
# 1  common_voice_luo_40556707.mp3
# 2  common_voice_luo_40558345.mp3
# 3  common_voice_luo_40558364.mp3
# 4  common_voice_luo_40558389.mp3
#
#                                          sentence_id  \
# 0  5c78f81439cd5d1a74d647448bf21f165abd55073835d6...
# 1  54b3b391c94a8ef9eb1cdb055b0facc12b5686caca6c50...
# 2  4f34d3506457318fa7f3a3ea29dbb7781e50aafd0d6f47...
# 3  54a371f19291fa92c6cb1f0a622b7fe7b7139a528427be...
# 4  53b244c1757ec63c177e1622a7122bd41c620242e6d614...
#
#                                     sentence sentence_domain  up_votes  \
# 0     mach maduong' chakore e mirni mar mach         general         2
# 1                  Chalo tugo nein kakaneni.         general         2
# 2  mag chokruogno oyie ni wechego gin adier.         general         2
# 3                                  Ijakanye?         general         2
# 4                       Be nitie chiemo eot?         general         2
#
#    down_votes       age gender  accents  variant locale  segment
# 0           0  twenties    NaN      NaN      NaN    luo      NaN
# 1           0  twenties    NaN      NaN      NaN    luo      NaN
# 2           1  twenties    NaN      NaN      NaN    luo      NaN
# 3           1  twenties    NaN      NaN      NaN    luo      NaN
# 4           0  twenties    NaN      NaN      NaN    luo      NaN

# %%
# Change the .mp3 extension to .wav in the 'path' column for all DataFrames
def replace_mp3_with_wav(df):
    if df is not None:
        # Replace '.mp3' with '.wav' in the 'path' column
        df['path'] = df['path'].str.replace('.mp3', '.wav', regex=False)
        print("Replaced .mp3 with .wav in the 'path' column.")
    return df

# Apply the function to each DataFrame
train_df = replace_mp3_with_wav(train_df)
test_df = replace_mp3_with_wav(test_df)
dev_df = replace_mp3_with_wav(dev_df)

# Optional: Print the updated first few rows of the DataFrames to verify
if train_df is not None:
    print(train_df.head())
if test_df is not None:
    print(test_df.head())
if dev_df is not None:
    print(dev_df.head())
# Out:
# Replaced .mp3 with .wav in the 'path' column.
# Replaced .mp3 with .wav in the 'path' column.
# Replaced .mp3 with .wav in the 'path' column.
#                                            client_id  \
# 0  76220259d4c614b1876412e489524ede62b700927b202d...
# 1  76220259d4c614b1876412e489524ede62b700927b202d...
# 2  76220259d4c614b1876412e489524ede62b700927b202d...
# 3  76220259d4c614b1876412e489524ede62b700927b202d...
# 4  76220259d4c614b1876412e489524ede62b700927b202d...
#
#                             path  \
# 0  common_voice_luo_40228998.wav
# 1  common_voice_luo_40228999.wav
# 2  common_voice_luo_40229003.wav
# 3  common_voice_luo_40229004.wav
# 4  common_voice_luo_40229005.wav
#
#                                          sentence_id  \
# 0  0b6d23f21850cf38f2da23b85e5b9d243e327f4e1a987c...
# 1  0093b37219cd1409b042fc7c111546d1338a34dfa32d04...
# 2  11417bdb395c6a8e9095f673662428f371c1ffea41a4d7...
# 3  1199d8ab1254d0772d3efa7f1f6113881809fc6c80aff5...
# 4  058ef183ec6c447b759aab31e64c8d9b1c0086828801d0...
#
#                                             sentence      sentence_domain  \
# 0  ber ka inyiso pachi kaluwore gi weche miwacho ...              general
# 1  Ne iparo ni gik ma kamago ne nyalo kelo chandr...              general
# 2     A. mar Bedo ng'at maduong' en gima tek ahinya.              general
# 3                         Nyaka bed ni nitie chik ma  technology_robotics
# 4    Sani weche mag ohala isomo embalariany ng’enyne              general
#
#    up_votes  down_votes  age gender  accents  variant locale  segment
# 0         2           0  NaN    NaN      NaN      NaN    luo      NaN
# 1         2           1  NaN    NaN      NaN      NaN    luo      NaN
# 2         2           0  NaN    NaN      NaN      NaN    luo      NaN
# 3         2           0  NaN    NaN      NaN      NaN    luo      NaN
# 4         2           0  NaN    NaN      NaN      NaN    luo      NaN
#                                            client_id  \
# 0  01d056dd20b981117632e060d72c99b78271c35d971f5c...
# 1  5084426734db1876936ae7bbdd72858a654bc46877a588...
# 2  95c77443ff068f953bfe4a14471b18f4cc94a08c74a771...
# 3  dd2c93e373aa566aed23d052723a253bc4a0ea604b8cbb...
# 4  d8dee50072545349474f2766b1e41c035e725eab1e68f3...
#
#                             path  \
# 0  common_voice_luo_40609150.wav
# 1  common_voice_luo_40636306.wav
# 2  common_voice_luo_40258074.wav
# 3  common_voice_luo_40833291.wav
# 4  common_voice_luo_40820771.wav
#
#                                          sentence_id  \
# 0  6a460e6ea255a011d13f980e2a317c35cb280d34b38772...
# 1  69ca449ccd58626ad3b0bdf9e787d00231d9dcf5082cca...
# 2  2d7ad3d79559dac77efe62807164187364c57e8fdf1ebc...
# 3  0b1db575a4a02a44caa5e0538da4754a121d7f251bab7f...
# 4  616c471e1f2909c0c168c5096123ca27ad56c9664ed880...
#
#                                             sentence       sentence_domain  \
# 0                               waduto wakalo e pek.               general
# 1                                  Wayu nyinge ng’a?               general
# 2                         Swahili e lando wach maber               general
# 3                            Ango motimo wang dheno.      agriculture_food
# 4  Ikruok ochako kawuono motelo ne chako ayanga p...  news_current_affairs
#
#    up_votes  down_votes       age gender  accents  variant locale  segment
# 0         2           0       NaN    NaN      NaN      NaN    luo      NaN
# 1         2           0  twenties    NaN      NaN      NaN    luo      NaN
# 2         2           0  twenties    NaN      NaN      NaN    luo      NaN
# 3         2           0  thirties    NaN      NaN      NaN    luo      NaN
# 4         2           0  thirties    NaN      NaN      NaN    luo      NaN
#                                            client_id  \
# 0  6d243f0d9779d2cfbffbe09729b57546067abca6c16f0d...
# 1  6d243f0d9779d2cfbffbe09729b57546067abca6c16f0d...
# 2  6d243f0d9779d2cfbffbe09729b57546067abca6c16f0d...
# 3  6d243f0d9779d2cfbffbe09729b57546067abca6c16f0d...
# 4  6d243f0d9779d2cfbffbe09729b57546067abca6c16f0d...
#
#                             path  \
# 0  common_voice_luo_40556704.wav
# 1  common_voice_luo_40556707.wav
# 2  common_voice_luo_40558345.wav
# 3  common_voice_luo_40558364.wav
# 4  common_voice_luo_40558389.wav
#
#                                          sentence_id  \
# 0  5c78f81439cd5d1a74d647448bf21f165abd55073835d6...
# 1  54b3b391c94a8ef9eb1cdb055b0facc12b5686caca6c50...
# 2  4f34d3506457318fa7f3a3ea29dbb7781e50aafd0d6f47...
# 3  54a371f19291fa92c6cb1f0a622b7fe7b7139a528427be...
# 4  53b244c1757ec63c177e1622a7122bd41c620242e6d614...
#
#                                     sentence sentence_domain  up_votes  \
# 0     mach maduong' chakore e mirni mar mach         general         2
# 1                  Chalo tugo nein kakaneni.         general         2
# 2  mag chokruogno oyie ni wechego gin adier.         general         2
# 3                                  Ijakanye?         general         2
# 4                       Be nitie chiemo eot?         general         2
#
#    down_votes       age gender  accents  variant locale  segment
# 0           0  twenties    NaN      NaN      NaN    luo      NaN
# 1           0  twenties    NaN      NaN      NaN    luo      NaN
# 2           1  twenties    NaN      NaN      NaN    luo      NaN
# 3           1  twenties    NaN      NaN      NaN    luo      NaN
# 4           0  twenties    NaN      NaN      NaN    luo      NaN

# %%
def clean_dataframe(df):
    # Retain only the 'path' and 'sentence' columns
    df = df[['path', 'sentence']].copy()

    # Remove leading/trailing whitespace in 'path' column
    df.loc[:, 'path'] = df['path'].str.strip()

    return df

# Clean each DataFrame
df_train_clean = clean_dataframe(train_df)
df_test_clean = clean_dataframe(test_df)
df_dev_clean = clean_dataframe(dev_df)

# Display the cleaned DataFrames
print("Cleaned Train DataFrame:")
print(df_train_clean.head())

print("\nCleaned Test DataFrame:")
print(df_test_clean.head())

print("\nCleaned Dev DataFrame:")
print(df_dev_clean.head())
# Out:
# Cleaned Train DataFrame:
#                             path  \
# 0  common_voice_luo_40228998.wav
# 1  common_voice_luo_40228999.wav
# 2  common_voice_luo_40229003.wav
# 3  common_voice_luo_40229004.wav
# 4  common_voice_luo_40229005.wav
#
#                                             sentence
# 0  ber ka inyiso pachi kaluwore gi weche miwacho ...
# 1  Ne iparo ni gik ma kamago ne nyalo kelo chandr...
# 2     A. mar Bedo ng'at maduong' en gima tek ahinya.
# 3                         Nyaka bed ni nitie chik ma
# 4    Sani weche mag ohala isomo embalariany ng’enyne
#
# Cleaned Test DataFrame:
#                             path  \
# 0  common_voice_luo_40609150.wav
# 1  common_voice_luo_40636306.wav
# 2  common_voice_luo_40258074.wav
# 3  common_voice_luo_40833291.wav
# 4  common_voice_luo_40820771.wav
#
#                                             sentence
# 0                               waduto wakalo e pek.
# 1                                  Wayu nyinge ng’a?
# 2                         Swahili e lando wach maber
# 3                            Ango motimo wang dheno.
# 4  Ikruok ochako kawuono motelo ne chako ayanga p...
#
# Cleaned Dev DataFrame:
#                             path                                   sentence
# 0  common_voice_luo_40556704.wav     mach maduong' chakore e mirni mar mach
# 1  common_voice_luo_40556707.wav                  Chalo tugo nein kakaneni.
# 2  common_voice_luo_40558345.wav  mag chokruogno oyie ni wechego gin adier.
# 3  common_voice_luo_40558364.wav                                  Ijakanye?
# 4  common_voice_luo_40558389.wav                       Be nitie chiemo eot?

# %%
# Step 6: Identify the entries in the 'path' columns
# Assuming the column is named 'path' and contains the full file paths (without extension)
train_paths = set(train_df['path'].str.split('/').str[-1].str.split('.').str[0])
test_paths = set(test_df['path'].str.split('/').str[-1].str.split('.').str[0])
dev_paths = set(dev_df['path'].str.split('/').str[-1].str.split('.').str[0])

# %%
# Step 7: Filter out entries where the 'path' does not correspond to an audio file in 'clips_wav'
train_filtered = train_df[train_df['path'].str.split('/').str[-1].str.split('.').str[0].isin(audio_files)]
test_filtered = test_df[test_df['path'].str.split('/').str[-1].str.split('.').str[0].isin(audio_files)]
dev_filtered = dev_df[dev_df['path'].str.split('/').str[-1].str.split('.').str[0].isin(audio_files)]

# Step 8: Output the results
print(f"Filtered Train DataFrame shape: {train_filtered.shape}")
print(f"Filtered Test DataFrame shape: {test_filtered.shape}")
print(f"Filtered Dev DataFrame shape: {dev_filtered.shape}")
# Out:
# Filtered Train DataFrame shape: (2498, 13)
# Filtered Test DataFrame shape: (734, 13)
# Filtered Dev DataFrame shape: (1570, 13)

# %%
def verify_paths(df, audio_files):
    # Extract the file name (without extension) from the 'path' column in the DataFrame
    paths = set(df['path'].str.split('/').str[-1].str.split('.').str[0])

    # Check for paths in the DataFrame that do not match any audio file name in the folder
    missing_files = paths.difference(audio_files)

    # Print a warning message if there are any missing files
    if len(missing_files) == 0:
        print("All paths in the DataFrame correspond to existing audio files.")
        return True
    else:
        print(f"Warning: There are {len(missing_files)} paths that do not correspond to any audio files in the folder: {missing_files}")
        return False

# Verify paths in train, test, and dev DataFrames
train_verified = verify_paths(train_df, audio_files)
test_verified = verify_paths(test_df, audio_files)
dev_verified = verify_paths(dev_df, audio_files)
# Out:
# Warning: There are 1553 paths that do not correspond to any audio files in the folder: {'common_voice_luo_40229072', 'common_voice_luo_40235122', 'common_voice_luo_40340936', 'common_voice_luo_40242739', 'common_voice_luo_40253461', 'common_voice_luo_40501822', 'common_voice_luo_40574145', 'common_voice_luo_40500301', 'common_voice_luo_40318376', 'common_voice_luo_40478146', 'common_voice_luo_40239218', 'common_voice_luo_40483717', 'common_voice_luo_40242775', 'common_voice_luo_40477914', 'common_voice_luo_40234690', 'common_voice_luo_40340745', 'common_voice_luo_40478474', 'common_voice_luo_40253283', 'common_voice_luo_40242957', 'common_voice_luo_40229597', 'common_voice_luo_40247486', 'common_voice_luo_40340762', 'common_voice_luo_40247402', 'common_voice_luo_40491077', 'common_voice_luo_40242815', 'common_voice_luo_40242872', 'common_voice_luo_40253025', 'common_voice_luo_40247519', 'common_voice_luo_40238689', 'common_voice_luo_40253107', 'common_voice_luo_40329939', 'common_voice_luo_40477999', 'common_voice_luo_40500114', 'common_voice_luo_40340808', 'common_voice_luo_40239275', 'common_voice_luo_40242793', 'common_voice_luo_40247232', 'common_voice_luo_40247367', 'common_voice_luo_40234748', 'common_voice_luo_40501087', 'common_voice_luo_40229813', 'common_voice_luo_40253102', 'common_voice_luo_40247428', 'common_voice_luo_40500883', 'common_voice_luo_40340747', 'common_voice_luo_40483691', 'common_voice_luo_40500979', 'common_voice_luo_40570677', 'common_voice_luo_40230042', 'common_voice_luo_40229447', 'common_voice_luo_40235409', 'common_voice_luo_40242738', 'common_voice_luo_40234810', 'common_voice_luo_40340728', 'common_voice_luo_40483040', 'common_voice_luo_40490913', 'common_voice_luo_40229497', 'common_voice_luo_40572765', 'common_voice_luo_40242926', 'common_voice_luo_40229806', 'common_voice_luo_40247273', 'common_voice_luo_40242764', 'common_voice_luo_40478454', 'common_voice_luo_40572391', 'common_voice_luo_40247412', 'common_voice_luo_40501754', 'common_voice_luo_40229911', 'common_voice_luo_40229415', 'common_voice_luo_40229586', 'common_voice_luo_40317105', 'common_voice_luo_40242743', 'common_voice_luo_40247400', 'common_voice_luo_40483107', 'common_voice_luo_40242949', 'common_voice_luo_40482971', 'common_voice_luo_40242895', 'common_voice_luo_40482833', 'common_voice_luo_40231900', 'common_voice_luo_40229356', 'common_voice_luo_40255556', 'common_voice_luo_40490938', 'common_voice_luo_40482753', 'common_voice_luo_40340770', 'common_voice_luo_40247278', 'common_voice_luo_40247415', 'common_voice_luo_40340838', 'common_voice_luo_40571886', 'common_voice_luo_40247512', 'common_voice_luo_40477953', 'common_voice_luo_40247376', 'common_voice_luo_40246225', 'common_voice_luo_40571107', 'common_voice_luo_40229795', 'common_voice_luo_40230010', 'common_voice_luo_40500145', 'common_voice_luo_40340856', 'common_voice_luo_40340727', 'common_voice_luo_40500317', 'common_voice_luo_40255600', 'common_voice_luo_40247245', 'common_voice_luo_40570911', 'common_voice_luo_40242850', 'common_voice_luo_40231824', 'common_voice_luo_40255552', 'common_voice_luo_40491188', 'common_voice_luo_40340737', 'common_voice_luo_40482958', 'common_voice_luo_40501292', 'common_voice_luo_40247395', 'common_voice_luo_40242787', 'common_voice_luo_40329969', 'common_voice_luo_40571130', 'common_voice_luo_40242810', 'common_voice_luo_40243007', 'common_voice_luo_40340773', 'common_voice_luo_40253266', 'common_voice_luo_40231377', 'common_voice_luo_40317868', 'common_voice_luo_40255542', 'common_voice_luo_40242807', 'common_voice_luo_40242905', 'common_voice_luo_40340801', 'common_voice_luo_40229028', 'common_voice_luo_40247171', 'common_voice_luo_40491408', 'common_voice_luo_40242754', 'common_voice_luo_40246176', 'common_voice_luo_40478191', 'common_voice_luo_40478477', 'common_voice_luo_40247440', 'common_voice_luo_40500482', 'common_voice_luo_40253215', 'common_voice_luo_40231435', 'common_voice_luo_40571072', 'common_voice_luo_40242772 ...
# Warning: There are 1807 paths that do not correspond to any audio files in the folder: {'common_voice_luo_40619264', 'common_voice_luo_40236589', 'common_voice_luo_40251044', 'common_voice_luo_40659063', 'common_voice_luo_40208982', 'common_voice_luo_40656454', 'common_voice_luo_40251083', 'common_voice_luo_40656371', 'common_voice_luo_40450696', 'common_voice_luo_40449672', 'common_voice_luo_40736083', 'common_voice_luo_40488630', 'common_voice_luo_40221967', 'common_voice_luo_40619328', 'common_voice_luo_40202228', 'common_voice_luo_40481087', 'common_voice_luo_40491682', 'common_voice_luo_40678534', 'common_voice_luo_40662242', 'common_voice_luo_40721729', 'common_voice_luo_40702889', 'common_voice_luo_40652644', 'common_voice_luo_40261097', 'common_voice_luo_40481034', 'common_voice_luo_40838750', 'common_voice_luo_40482936', 'common_voice_luo_40665095', 'common_voice_luo_40561218', 'common_voice_luo_40261059', 'common_voice_luo_40261105', 'common_voice_luo_40487644', 'common_voice_luo_40202264', 'common_voice_luo_40593104', 'common_voice_luo_40640985', 'common_voice_luo_40665150', 'common_voice_luo_40626818', 'common_voice_luo_40604482', 'common_voice_luo_40604816', 'common_voice_luo_40561118', 'common_voice_luo_40479256', 'common_voice_luo_40211072', 'common_voice_luo_40594890', 'common_voice_luo_40594852', 'common_voice_luo_40619009', 'common_voice_luo_40250982', 'common_voice_luo_40494418', 'common_voice_luo_40795469', 'common_voice_luo_40640758', 'common_voice_luo_40992192', 'common_voice_luo_40202254', 'common_voice_luo_40594078', 'common_voice_luo_40494646', 'common_voice_luo_40202261', 'common_voice_luo_40679303', 'common_voice_luo_40250970', 'common_voice_luo_40701702', 'common_voice_luo_40237906', 'common_voice_luo_40684755', 'common_voice_luo_40488783', 'common_voice_luo_40251043', 'common_voice_luo_40703222', 'common_voice_luo_40681321', 'common_voice_luo_40494420', 'common_voice_luo_40692900', 'common_voice_luo_40251048', 'common_voice_luo_40774180', 'common_voice_luo_40664258', 'common_voice_luo_40682336', 'common_voice_luo_40485205', 'common_voice_luo_40627459', 'common_voice_luo_40450878', 'common_voice_luo_40652237', 'common_voice_luo_40491854', 'common_voice_luo_40484716', 'common_voice_luo_40632394', 'common_voice_luo_40493296', 'common_voice_luo_40718350', 'common_voice_luo_40661178', 'common_voice_luo_40237862', 'common_voice_luo_40251007', 'common_voice_luo_40691001', 'common_voice_luo_40667245', 'common_voice_luo_40250976', 'common_voice_luo_40604644', 'common_voice_luo_40477536', 'common_voice_luo_40991644', 'common_voice_luo_40604775', 'common_voice_luo_40657561', 'common_voice_luo_40724379', 'common_voice_luo_40237902', 'common_voice_luo_40250998', 'common_voice_luo_40251047', 'common_voice_luo_40666988', 'common_voice_luo_40664551', 'common_voice_luo_40604647', 'common_voice_luo_40236572', 'common_voice_luo_40442090', 'common_voice_luo_40679439', 'common_voice_luo_40485227', 'common_voice_luo_40237948', 'common_voice_luo_40619271', 'common_voice_luo_40655330', 'common_voice_luo_40478764', 'common_voice_luo_40752741', 'common_voice_luo_40444925', 'common_voice_luo_40657237', 'common_voice_luo_40261058', 'common_voice_luo_40449158', 'common_voice_luo_40656926', 'common_voice_luo_40594681', 'common_voice_luo_40211071', 'common_voice_luo_40236588', 'common_voice_luo_40636306', 'common_voice_luo_40237926', 'common_voice_luo_40655802', 'common_voice_luo_40211089', 'common_voice_luo_40251028', 'common_voice_luo_40686189', 'common_voice_luo_40208975', 'common_voice_luo_40444175', 'common_voice_luo_40447109', 'common_voice_luo_40652570', 'common_voice_luo_40251051', 'common_voice_luo_40626732', 'common_voice_luo_40251040', 'common_voice_luo_40652689', 'common_voice_luo_40491229', 'common_voice_luo_40561448', 'common_voice_luo_40211093', 'common_voice_luo_40208984', 'common_voice_luo_40477579', 'common_voice_luo_40594843', 'common_voice_luo_40261092', 'common_voice_luo_40251039', 'common_voice_luo_40604834 ...
# Warning: There are 1490 paths that do not correspond to any audio files in the folder: {'common_voice_luo_40578794', 'common_voice_luo_40482373', 'common_voice_luo_40565201', 'common_voice_luo_40562100', 'common_voice_luo_40567124', 'common_voice_luo_40565051', 'common_voice_luo_40565668', 'common_voice_luo_40482495', 'common_voice_luo_40564232', 'common_voice_luo_40561795', 'common_voice_luo_40565150', 'common_voice_luo_40565254', 'common_voice_luo_40482317', 'common_voice_luo_40486238', 'common_voice_luo_40565895', 'common_voice_luo_40481479', 'common_voice_luo_40570534', 'common_voice_luo_40565461', 'common_voice_luo_40566829', 'common_voice_luo_40481106', 'common_voice_luo_40577494', 'common_voice_luo_40567149', 'common_voice_luo_40485809', 'common_voice_luo_40481029', 'common_voice_luo_40574070', 'common_voice_luo_40561257', 'common_voice_luo_40576753', 'common_voice_luo_40575493', 'common_voice_luo_40577187', 'common_voice_luo_40570163', 'common_voice_luo_40485667', 'common_voice_luo_40561006', 'common_voice_luo_40566857', 'common_voice_luo_40578176', 'common_voice_luo_40481112', 'common_voice_luo_40482792', 'common_voice_luo_40574821', 'common_voice_luo_40482460', 'common_voice_luo_40566678', 'common_voice_luo_40566669', 'common_voice_luo_40573546', 'common_voice_luo_40567167', 'common_voice_luo_40567242', 'common_voice_luo_40566023', 'common_voice_luo_40561323', 'common_voice_luo_40478340', 'common_voice_luo_40565507', 'common_voice_luo_40577572', 'common_voice_luo_40482458', 'common_voice_luo_40482690', 'common_voice_luo_40480927', 'common_voice_luo_40566986', 'common_voice_luo_40498973', 'common_voice_luo_40576650', 'common_voice_luo_40565224', 'common_voice_luo_40478384', 'common_voice_luo_40575481', 'common_voice_luo_40577820', 'common_voice_luo_40567232', 'common_voice_luo_40482549', 'common_voice_luo_40567039', 'common_voice_luo_40576616', 'common_voice_luo_40577621', 'common_voice_luo_40570147', 'common_voice_luo_40577420', 'common_voice_luo_40565077', 'common_voice_luo_40566843', 'common_voice_luo_40562292', 'common_voice_luo_40567055', 'common_voice_luo_40567032', 'common_voice_luo_40565512', 'common_voice_luo_40565871', 'common_voice_luo_40565193', 'common_voice_luo_40563313', 'common_voice_luo_40564442', 'common_voice_luo_40482512', 'common_voice_luo_40565463', 'common_voice_luo_40482509', 'common_voice_luo_40564299', 'common_voice_luo_40565424', 'common_voice_luo_40565574', 'common_voice_luo_40487103', 'common_voice_luo_40565889', 'common_voice_luo_40481307', 'common_voice_luo_40486241', 'common_voice_luo_40565286', 'common_voice_luo_40566028', 'common_voice_luo_40567567', 'common_voice_luo_40570554', 'common_voice_luo_40561490', 'common_voice_luo_40577571', 'common_voice_luo_40565417', 'common_voice_luo_40565010', 'common_voice_luo_40567084', 'common_voice_luo_40489643', 'common_voice_luo_40570462', 'common_voice_luo_40481196', 'common_voice_luo_40482679', 'common_voice_luo_40565339', 'common_voice_luo_40562070', 'common_voice_luo_40561963', 'common_voice_luo_40565499', 'common_voice_luo_40561258', 'common_voice_luo_40482624', 'common_voice_luo_40569755', 'common_voice_luo_40566682', 'common_voice_luo_40570395', 'common_voice_luo_40482711', 'common_voice_luo_40565243', 'common_voice_luo_40489706', 'common_voice_luo_40565352', 'common_voice_luo_40578841', 'common_voice_luo_40561630', 'common_voice_luo_40563359', 'common_voice_luo_40489707', 'common_voice_luo_40564347', 'common_voice_luo_40578212', 'common_voice_luo_40566935', 'common_voice_luo_40566845', 'common_voice_luo_40576042', 'common_voice_luo_40481353', 'common_voice_luo_40566584', 'common_voice_luo_40565216', 'common_voice_luo_40478360', 'common_voice_luo_40482362', 'common_voice_luo_40564850', 'common_voice_luo_40564992', 'common_voice_luo_40578192', 'common_voice_luo_40482469', 'common_voice_luo_40561391', 'common_voice_luo_40573874', 'common_voice_luo_40565627', 'common_voice_luo_40577251', 'common_voice_luo_40482717', 'common_voice_luo_40573876 ...

# %%
# Step 10: Save the filtered DataFrames to new TSV files, regardless of verification
train_filtered.to_csv('/content/filtered_train.tsv', sep='\t', index=False)
test_filtered.to_csv('/content/filtered_test.tsv', sep='\t', index=False)
dev_filtered.to_csv('/content/filtered_dev.tsv', sep='\t', index=False)

print("Filtered data has been saved to new TSV files, regardless of path verification.")
# Out:
# Filtered data has been saved to new TSV files, regardless of path verification.
